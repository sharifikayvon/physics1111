# %%
from function_suite import makeplot

# %%
xdata  = [1,2,3,4,5]
ydata  = [2,4,6,8,10]
xlabel = 'Time (s)'
ylabel = 'Position (m)'
title  = 'Position vs. Time'
fitline = True
fitquad = True


makeplot(xdata,
         ydata,
         xlabel,
         ylabel,
         title,
         fitline,
         fitquad,
         )
